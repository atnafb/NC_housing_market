# %%
import pandas as pd

NC_houseDF = pd.read_csv("Data Source/NC_data.csv")
NC_houseDF.head()
# Out:
#   period_begin  period_end       city           state  median_sale_price  \
# 0   2024-12-01  2024-12-31  Charlotte  North Carolina           389820.0
# 1   2023-02-01  2023-02-28  Charlotte  North Carolina           560000.0
# 2   2024-07-01  2024-07-31  Charlotte  North Carolina           405000.0
# 3   2021-03-01  2021-03-31  Charlotte  North Carolina           304500.0
# 4   2024-03-01  2024-03-31  Charlotte  North Carolina           335500.0
#
#    median_list_price  median_ppsf  median_list_ppsf  homes_sold  \
# 0           395000.0   228.108644        230.832646       174.0
# 1           399900.0   286.298569        225.218023         3.0
# 2           400000.0   237.651187        240.014793       204.0
# 3           330000.0   169.445628        189.646064       272.0
# 4           420000.0   330.619974        246.101937       136.0
#
#    pending_sales  new_listings  inventory  months_of_supply  median_dom  \
# 0            NaN         147.0      561.0               3.2        52.0
# 1            NaN           4.0       10.0               3.3        18.0
# 2            NaN         249.0      609.0               3.0        39.0
# 3            NaN         293.0      518.0               1.9        35.0
# 4            NaN         172.0      304.0               2.2        34.0
#
#    avg_sale_to_list  sold_above_list  off_market_in_two_weeks  population
# 0          0.983007         0.126437                 0.200000   1436613.0
# 1          1.023028         0.666667                 0.400000   1436613.0
# 2          0.989842         0.191176                 0.424779   1436613.0
# 3          1.010810         0.466912                 0.655844   1436613.0
# 4          0.986313         0.279412                 0.553191   1436613.0

# %% [markdown]
# ## Clean the dataset

# %%
#coy the df
NC_houseDF1 = NC_houseDF.copy()

# %%
# convert the data and create year month key 
NC_houseDF1['period_begin'] = pd.to_datetime(NC_houseDF1['period_begin'])

# %%
#Creating year_month column 
NC_houseDF1['year_month'] = NC_houseDF1['period_begin'].dt.to_period('M')

# %%
# gettomg the importnat columns for the analysis 
NC_df = NC_houseDF1[[
    'year_month',
    'city',
    'state',
    'median_sale_price',
    'median_list_price',
    'median_ppsf',
    'median_list_ppsf',
    'homes_sold',
    'new_listings',
    'inventory',
    'months_of_supply',
    'median_dom',
    'avg_sale_to_list',
    'sold_above_list',
    'off_market_in_two_weeks',
    'population'
]]

# %%
NC_df.dtypes
# Out:
# year_month                 period[M]
# city                          object
# state                         object
# median_sale_price            float64
# median_list_price            float64
# median_ppsf                  float64
# median_list_ppsf             float64
# homes_sold                   float64
# new_listings                 float64
# inventory                    float64
# months_of_supply             float64
# median_dom                   float64
# avg_sale_to_list             float64
# sold_above_list              float64
# off_market_in_two_weeks      float64
# population                   float64
# dtype: object
